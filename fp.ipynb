# %% [markdown]
# # ANALISIS DIAGNOSTIK FAKTOR PENYEBAB & PEMODELAN PREDIKTIF TINGKAT PUBLIKASI JURNAL DOSEN ITS

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot
import os 
import glob
from sklearn.cluster import KMeans
# !pip3 install joypy
import joypy

# %% [markdown]
# ## Load Dataset

# %%
# Load the data
# Data is stored in 'data_journal'
data_journal = pd.read_csv('author_book.csv', delimiter =';')
data_journal
# Out:
#      id_buku           isbn  \
# 0      38569  9786025022128
# 1      36208  9786024011499
# 2      92375  9786233900171
# 3      43161  9786026715951
# 4      96684  9786237060772
# ..       ...            ...
# 362    85279  9786021062999
# 363   139460  9786239953003
# 364   139459  9786239953058
# 365   139474  9786232125766
# 366   139471  9786232129559
#
#                                                  title  \
# 0                                              KIMIA 1
# 1                       Karakterisasi Struktur Padatan
# 2                         Pengantar pembelajaran mesin
# 3    Bioinformatika : perspektif matematika pada an...
# 4                            Pengolahan sinyal digital
# ..                                                 ...
# 362                                            Separuh
# 363  Analisa Kekuatan Konstruksi Deck Kapal Tongkan...
# 364  Engineering Critical Assessment Instalasi Pipa...
# 365                    Perspective [sumber elektronik]
# ...

# %%
data_journal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_buku                 367 non-null    int64
#  1   isbn                    367 non-null    object
#  2   title                   367 non-null    object
#  3   penulis_full            364 non-null    object
#  4   tempat                  316 non-null    object
#  5   penerbit                367 non-null    object
#  6   year                    367 non-null    int64
#  7   sinta_id                367 non-null    int64
#  8   _sys_date_processed     367 non-null    object
#  9   category                137 non-null    object
#  10  nama_versi_kepegawaian  358 non-null    object
#  11  nama_versi_akademik     358 non-null    object
#  12  jenis_pegawai           358 non-null    object
#  13  jurusan                 358 non-null    object
# ...

# %% [markdown]
# ## Informasi Kolom dan Baris

# %%
print(data_journal.columns)
print(data_journal.index)
# Out:
# Index(['id_buku', 'isbn', 'title', 'penulis_full', 'tempat', 'penerbit',
#        'year', 'sinta_id', '_sys_date_processed', 'category',
#        'nama_versi_kepegawaian', 'nama_versi_akademik', 'jenis_pegawai',
#        'jurusan', 'fakultas'],
#       dtype='object')
# RangeIndex(start=0, stop=367, step=1)

# %%
# Filtering Each Faculty
# Faculty of Science (Fakulatas Sains dan Analitika Data)
data_journal_fsad = data_journal[data_journal['fakultas'] == 'Fakultas Sains dan Analitika Data']
data_journal_fsad
# Out:
#      id_buku           isbn  \
# 0      38569  9786025022128
# 1      36208  9786024011499
# 2      92375  9786233900171
# 3      43161  9786026715951
# 34     38569  9786025022128
# ..       ...            ...
# 343    48017  9786027430945
# 344    38569  9786025022128
# 351    71998  9786025542527
# 355    55414  9789793980270
# 358    98853  9786239727710
#
#                                                  title  \
# 0                                              KIMIA 1
# 1                       Karakterisasi Struktur Padatan
# 2                         Pengantar pembelajaran mesin
# 3    Bioinformatika : perspektif matematika pada an...
# 34                                             KIMIA 1
# ..                                                 ...
# 343             SMART CITY: KONSEP, MODEL, & TEKNOLOGI
# 344                                            KIMIA 1
# 351            Pengembangan bahan karbon dari biomassa
# 355   Penyajian informatif tabel, grafik dan statistik
# ...

# %%
data_journal_fsad.head()
# Out:
#     id_buku           isbn                                              title  \
# 0     38569  9786025022128                                            KIMIA 1
# 1     36208  9786024011499                     Karakterisasi Struktur Padatan
# 2     92375  9786233900171                       Pengantar pembelajaran mesin
# 3     43161  9786026715951  Bioinformatika : perspektif matematika pada an...
# 34    38569  9786025022128                                            KIMIA 1
#
#                                          penulis_full      tempat  \
# 0                             Taslim Ersam...[et al.]    Surabaya
# 1   Didik Prasetyoko, Hamzah Fansuri, Yatim Lailun...  Yogyakarta
# 2                         Penulis Mohammad Isa Irawan         NaN
# 3                        Oleh Siti Amiroch...[et al.]    Lamongan
# 34                            Taslim Ersam...[et al.]    Surabaya
#
#                 penerbit  year  sinta_id  _sys_date_processed        category  \
# ...

# %%
data_journal_fsad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 358
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_buku                 93 non-null     int64
#  1   isbn                    93 non-null     object
#  2   title                   93 non-null     object
#  3   penulis_full            92 non-null     object
#  4   tempat                  86 non-null     object
#  5   penerbit                93 non-null     object
#  6   year                    93 non-null     int64
#  7   sinta_id                93 non-null     int64
#  8   _sys_date_processed     93 non-null     object
#  9   category                59 non-null     object
#  10  nama_versi_kepegawaian  93 non-null     object
#  11  nama_versi_akademik     93 non-null     object
#  12  jenis_pegawai           93 non-null     object
#  13  jurusan                 93 non-null     object
# ...

# %%
data_journal_fsad.describe()
# Out:
#              id_buku         year      sinta_id
# count      93.000000    93.000000  9.300000e+01
# mean    73339.612903  2016.946237  5.781407e+06
# std     40246.479407     4.559666  1.237019e+06
# min       505.000000  1994.000000  2.896300e+04
# 25%     38569.000000  2016.000000  5.976202e+06
# 50%     59292.000000  2018.000000  5.980047e+06
# 75%     96540.000000  2020.000000  5.998915e+06
# max    143617.000000  2022.000000  6.728295e+06

# %%
# Checking measures of availability in column 'fakultas'
number_data_journal = data_journal_fsad['fakultas']

# Range
data_range = np.ptp(number_data_journal)

# Standard Deviation    
# data_std = np.std(data_journal_fsad['tahun'])

#Variance
# data_var = np.var(data_journal_fsad['tahun'])

# Interquartile Range (IQR)
# Q1 = data_journal_fsad['tahun'].quantile(0.25)
# Q3 = data_journal_fsad['tahun'].quantile(0.75)
# IQR = Q3 - Q1

# Show Resluts
# print('Number of data:', number_data_journal)
# print('Range:', data_range)
# print('Standard Deviation:', data_std)
# print('Variance:', data_var)
# print('Interquartile Range (IQR):', IQR)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[86], line 5
#       2 number_data_journal = data_journal_fsad['fakultas']
#       4 # Range
# ----> 5 data_range = np.ptp(number_data_journal)
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2684, in ptp(a, axis, out, keepdims)
#    2682     else:
#    2683         return ptp(axis=axis, out=out, **kwargs)
# -> 2684 return _methods._ptp(a, axis=axis, out=out, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:219, in _ptp(a, axis, out, keepdims)
#     218 def _ptp(a, axis=None, out=None, keepdims=False):
# --> 219     return um.subtract(
#     220         umr_maximum(a, axis, None, out, keepdims),
#     221         umr_minimum(a, axis, None, None, keepdims),
#     222         out
#     223     )
#
# ...
